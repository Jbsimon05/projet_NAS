# %%
import os
import shutil
import time

def get_number_file(nom_fichier):
    """
    Extract the number from the filename if it is in the correct format.
    Args:
        nom_fichier (str): The filename.
    Returns:
        int: The extracted number if the filename is correct, None otherwise.
    """
    if nom_fichier in correct_files:
        return int(nom_fichier[1:2])
    else:
        return None

def compare_and_paste(dossier_source, dossier_destination):
    """
    Compare files in the source and destination directories and move them if necessary.
    Args:
        dossier_source (str): The source directory.
        dossier_destination (str): The destination directory.
    """
    noms_fichiers = os.listdir(os.path.join(os.getcwd(), dossier_destination))
    for nom_fichier in noms_fichiers:
        numero_fichier = get_number_file(nom_fichier)
        print(nom_fichier, numero_fichier)
        if numero_fichier is not None:
            chemin_fichier_source = os.path.join(dossier_source, nom_fichier)
            chemin_fichier_destination = os.path.join(dossier_destination, f"i{numero_fichier}_startupconfig.cfg")

            try:
                if os.path.exists(chemin_fichier_destination):
                    os.remove(chemin_fichier_destination)
                shutil.copy2(chemin_fichier_source, dossier_destination)
                print(f"Le fichier {nom_fichier} a été déplacé vers {dossier_destination}")
            except FileNotFoundError:
                print(f"Le fichier {nom_fichier} n'existe pas.")
            except PermissionError:
                print(f"Vous n'avez pas la permission de déplacer le fichier {nom_fichier}.")


start = time.time()

path_correct_files = os.path.join(os.getcwd())
correct_files = os.listdir(path_correct_files)

# Dossier GNS3
path_dossier_principal = r"C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips"
dossiers = os.listdir(path_dossier_principal)

for nom_dossier in dossiers:
    path_dossier_destination = os.path.join(path_dossier_principal, nom_dossier, "configs")
    if os.path.exists(path_dossier_destination):
        compare_and_paste(path_correct_files, path_dossier_destination)

end = time.time()
print("temps d'execution :", end-start)
# Out:
# i13_startup-config.cfg 1
# Le fichier i13_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\24a179e3-a1cd-4b47-b0f3-eaca5aa9b4d6\configs
# i7_startup-config.cfg 7
# Le fichier i7_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\3ffcbd07-6087-4efb-a4f4-4932529f3252\configs
# i11_startup-config.cfg 1
# Le fichier i11_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\4754abd0-0297-4741-8538-6cffa7e9fdf9\configs
# i9_startup-config.cfg 9
# Le fichier i9_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\53096d43-7045-46ed-b5f4-5597e4cb2ea6\configs
# i2_startup-config.cfg 2
# Le fichier i2_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\7c59d511-dc5c-4836-a320-4fb9395ec9d6\configs
# i10_startup-config.cfg 1
# Le fichier i10_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\8b0ddcd1-6e7a-4fb2-85ad-8de0024e0397\configs
# i4_private-config.cfg None
# i4_startup-config.cfg 4
# Le fichier i4_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\930cd219-e161-459b-8ea9-e4d3a44241c7\configs
# i3_startup-config.cfg 3
# Le fichier i3_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\9bcb1ecb-f964-4c18-b0a7-539133773c7e\configs
# i14_startup-config.cfg 1
# Le fichier i14_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\a786893f-017c-4f7d-a439-1b396ec48bb8\configs
# i8_private-config.cfg None
# i8_startup-config.cfg 8
# Le fichier i8_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\b0a976c4-c15f-4fd1-bca6-93778602b086\configs
# i1_startup-config.cfg 1
# Le fichier i1_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\b733807e-0d8e-4908-8707-4099a98d619e\configs
# i12_startup-config.cfg 1
# Le fichier i12_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\e126fde9-dbe3-4c76-829f-479d458d42c6\configs
# i5_startup-config.cfg 5
# Le fichier i5_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\e5bffd65-1541-4746-a36c-1f2c1e7699b9\configs
# i6_private-config.cfg None
# i6_startup-config.cfg 6
# Le fichier i6_startup-config.cfg a été déplacé vers C:\Users\User\GNS3\projects\quatorze_routeurs\project-files\dynamips\fc195d66-21b0-4e44-98bb-5478d85a74ae\configs
# temps d'execution : 0.014952659606933594
